# %%
from xrsana import xrs_read, xrs_extraction
# Out:
#
#  ############################# Welcome to XRStools #############################
#  # If you are using this software, please cite the following work:             #
#  # Ch.J. Sahle, A. Mirone, J. Niskanen, J. Inkinen, M. Krisch, and S. Huotari: #
#  # "Planning, performing, and analyzing X-ray Raman scattering experiments."   #
#  # Journal of Synchrotron Radiation 22, No. 2 (2015): 400-409.                 #
#  ###############################################################################

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
path = '/home/hushiqi/work/forked_xrstools/XRStools/LERIX-Guide/graphite/'

# %%
myq = [2,5,8,9,10]

# %%
cnt = xrs_read.read_lerix(exp_dir=path,elastic_name='elastic',nixs_name='NIXS',wide_name='wide')

# %%
cnt.load_elastics(analyzers=myq)
#get E0 and FWHM of peaks to be used in gaussian fitting script
# MAKE SURE TO SAVE TO DOCUMENT
# Out:
# Reading elastic scan:  elastic.0001
# Reading elastic scan:  elastic.0002
# Reading elastic scan:  elastic.0003
# Reading elastic scan:  elastic.0004
# Reading elastic scan:  elastic.0005
# Running 'Update_Cenom' Script for analysers: [2, 5, 8, 9, 10]
# E0 was found to be (keV):  9.89036412493722
# Average FWHM for the elastics is (eV):  0.7198765740376984

# %%
# load all elastics, nixs and wides in one go
cnt.load_elastics(analyzers='all')
cnt.load_nixs()
cnt.load_wides()
# Out:
# Reading elastic scan:  elastic.0001
# Reading elastic scan:  elastic.0002
# Reading elastic scan:  elastic.0003
# Reading elastic scan:  elastic.0004
# Reading elastic scan:  elastic.0005
# Running 'Update_Cenom' Script for All analysers
# E0 was found to be (keV):  9.890364103581122
# Average FWHM for the elastics is (eV):  0.6370750858768588
# Reading NIXS scan:  NIXS.0001
# Reading NIXS scan:  NIXS.0002
# Reading NIXS scan:  NIXS.0003
# Reading Wide scan:  wide.0001

# %%
cnt.join_nixs_wide(scaling='auto')
# Out:
# Successfully joined the wide and nixs scans.

# %%
# TEST ANALYSERS
#matplotlib backend is configured in the setup cell
plt.plot(cnt.eloss,cnt.signals[:,[4]]) #interactive plot window to look at each analyser output
plt.show()
# Out:
# <div id='0686451c-6a33-44b2-bff8-a5e9310f6033'></div>

# %%
# matplotlib backend is configured in the setup cell
plt.plot(cnt.eloss,cnt.signals[:,[2,5,8]]) #interactive plot window to look at each analyser output
plt.show()
# Out:
# <div id='42a2cfdf-db22-4447-84e8-e243bbf9b094'></div>

# %%
cnt.save_H5(H5name='PS_CNT_369_TAKE2')

# %%
cnt.update_cenom(analyzers='all')
# Out:
# Running 'Update_Cenom' Script for All analysers
# E0 was found to be (keV):  9.890364103581122
# Average FWHM for the elastics is (eV):  0.6370750858768588

# %%
cnt_ex = xrs_extraction.edge_extraction(cnt,['C'],[1.0],{'C':['K']})

# %%
from xrsana import xrs_extraction

# %%
cnt_ex.analyzerAverage([2,5,8],errorweighing=False)

# %%
# matplotlib backend is configured in the setup cell
cnt_ex.removeCorePearsonAv('C','K',[150,280.0],[330.0,450.0],weights=[2,1],HFcore_shift=5.6,scaling=5.9)
# Out:
# <div id='52c615cd-f003-4a8d-8ebc-8f5a00c60fa4'></div>
# The fit parameters are:  [-2.41920426e+02  2.82723193e+02  5.36746124e+00  6.06235810e+01
#   2.96936033e-04  2.56649344e-04  5.89508309e+00]
# /home/hushiqi/work/xrs_ana/xrsana/math_functions.py:175: RuntimeWarning: overflow encountered in scalar power
#   y = a[3] * (1.0+(2.0**(1.0/a[2])-1.0) * (2.0*(x-a[0])/a[1])**2.0)**(-a[2])
# /home/hushiqi/work/xrs_ana/xrsana/math_functions.py:175: RuntimeWarning: divide by zero encountered in scalar divide
#   y = a[3] * (1.0+(2.0**(1.0/a[2])-1.0) * (2.0*(x-a[0])/a[1])**2.0)**(-a[2])
# /home/hushiqi/work/xrs_ana/xrsana/math_functions.py:175: RuntimeWarning: divide by zero encountered in divide
#   y = a[3] * (1.0+(2.0**(1.0/a[2])-1.0) * (2.0*(x-a[0])/a[1])**2.0)**(-a[2])

# %%
cnt_ex.save_average_Sqw(os.path.join(path,'PSCNT_data[369]_extract_BETTERSUBTRACT.dat'), emin=275,emax=340)

# %%
cnt_ex.sqwav
# Out:
# array([-6.55440613e+00, -8.05861161e+00, -7.81214604e+00, -7.17895395e+00,
#        -6.38924328e+00, -5.83938505e+00, -5.29929727e+00, -4.76052626e+00,
#        -4.24725813e+00, -3.47111525e+00, -2.98281320e+00, -2.51930720e+00,
#        -2.16026568e+00, -2.25596112e+00, -2.23433412e+00, -2.06512140e+00,
#        -1.84966934e+00, -1.81760731e+00, -1.74920966e+00, -1.56477919e+00,
#        -1.45006652e+00, -1.35177484e+00, -1.33694039e+00, -1.26993528e+00,
#        -1.13724777e+00, -1.01844023e+00, -9.47812111e-01, -8.03621293e-01,
#        -6.98087331e-01, -6.11655630e-01, -5.54466861e-01, -5.08898171e-01,
#        -3.68042852e-01, -2.47577508e-01, -2.93952662e-01, -2.27403949e-01,
#        -1.82993339e-01, -1.51006264e-01, -4.78979629e-02, -1.10642305e-02,
#        -2.25397774e-02, -7.21710980e-02,  5.79953566e-02,  8.13322626e-02,
#        -6.08700050e-03,  1.75785975e-02, -3.62087170e-02,  4.09892038e-02,
#        -2.91555964e-03, -6.14105767e-02,  3.14439720e-02, -2.40124983e-05,
#         1.43362160e-02, -5.46862945e-02,  3.06462749e-03, -5.05062080e-02,
#        -2.02583583e-02, -1.62857124e-02,  2.67428127e-02, -2.68745724e-02,
#         1.66131269e-02,  1.15648136e-02,  2.38504030e-02, -1.88715318e-02,
#        -6.33964248e-03,  8.27395924e-03,  6.65142746e-03,  4.14560041e-02,
#         1.56483474e-02,  2.35978812e-03, -2.16822101e-02, -9.46483941e-03,
#        -1.14164109e-02, -2.51949464e-02, -4.66319618e-06,  4.61821759e-02,
#         7.19010276e-03,  2.40489920e-02, -4.25245356e-03,  3.23847112e-02,
#        -9.30119952e-03,  2.15402185e-02,  1.78519329e-02,  2.80180433e-02,
#        -4.20609237e-02,  2.47809244e-03, -3.86241051e-02, -4.01904613e-02,
#        -4.01408801e-02, -4.28216341e-02, -4.56170637e-02, -4.43963912e-02,
#        -4.63459628e-02, -4.94725905e-02, -5.02192036e-02, -5.09996228e-02,
#        -5.11416214e-02, -5.29102808e-02, -5.26130217e-02, -6.11439607e-02,
#        -5.81663109e-02, -5.92914462e-02, -6.06095461e-02, -6.29123315e-02,
#        -6.15460955e-02, -6.24532315e-02, -6.38014685e-02, -6.27774680e-02,
#        -6.54622476e-02, -6.25642309e-02, -6.19350960e-02, -6.03592158e-02,
#        -6.71718161e-02, -6.66975705e-02, -6.48860967e-02, -6.45936193e-02,
#        -6.47169874e-02, -6.56668087e-02, -6.69635939e-02, -6.60398346e-02,
#        -6.44590443e-02, -6.38074531e-02, -6.45376061e-02, -6.35289342e-02,
#        -6.59543588e-02, -6.50169134e-02, -6.90620197e-02, -6.54985416e-02,
#        -6.49433807e-02, -6.67442462e-02, -6.66294798e-02, -6.55557899e-02,
#        -6.79164475e-02, -6.79656767e-02, -6.66809416e-02, -6.37722519e-02,
#        -6.88699059e-02, -6.93688730e-02, -6.95279883e-02, -6.44792818e-02,
#        -6.77537911e-02, -6.45182472e-02, -6.76566742e-02, -6.68578569e-02,
#        -6.85818613e-02, -6.64058208e-02, -6.78770346e-02, -6.52862164e-02,
#        -6.52390631e-02, -6.62652698e-02, -6.84871696e-02, -6.89352884e-02,
#        -6.98256694e-02, -6.59753649e-02, -6.89847183e-02, -6.41627389e-02,
#        -6.66306147e-02, -6.73542977e-02, -6.83838427e-02, -6.19652234e-02,
#        -5.92716878e-02, -5.76998173e-02, -5.75328283e-02, -5.08265725e-02,
#        -3.89851389e-02, -2.70572143e-02, -7.02125594e-03,  2.74070532e-02,
#         6.59074922e-02,  1.21633583e-01,  1.94527697e-01,  2.63905226e-01,
#         3.53649956e-01,  4.55923641e-01,  5.28369967e-01,  5.93758871e-01,
#         6.52299277e-01,  6.65778907e-01,  6.60698098e-01,  6.18416044e-01,
#         5.47859115e-01,  4.60045604e-01,  3.84669197e-01,  3.18314060e-01,
#         2.74667392e-01,  2.44927130e-01,  2.18893417e-01,  2.01494894e-01,
#         1.89330277e-01,  1.85829323e-01,  1.68480634e-01,  1.66596078e-01,
#         1.61875193e-01,  1.57853953e-01,  1.55584966e-01,  1.55489357e-01,
#         1.49395824e-01,  1.47859129e-01,  1.46616279e-01,  1.47792171e-01,
#         1.46586128e-01,  1.38487303e-01,  1.40771579e-01,  1.37481681e-01,
#         1.33094984e-01,  1.32183859e-01,  1.39135181e-01,  1.34950527e-01,
#         1.30421242e-01,  1.33080827e-01,  1.27557784e-01,  1.30963593e-01,
#         1.25156105e-01,  1.34557271e-01,  1.24110684e-01,  1.28037179e-01,
#         1.23293537e-01,  1.22511213e-01,  1.24509327e-01,  1.22173257e-01,
#         1.20615157e-01,  1.20651404e-01,  1.17692516e-01,  1.18214362e-01,
#         1.19100632e-01,  1.20582970e-01,  1.16434043e-01,  1.15996860e-01,
#         1.17829757e-01,  1.21742936e-01,  1.30604123e-01,  1.32627624e-01,
#         1.40461215e-01,  1.44063135e-01,  1.72927357e-01,  1.89675811e-01,
#         2.26015787e-01,  2.69521429e-01,  3.01775194e-01,  3.41980267e-01,
#         3.71309567e-01,  3.95566154e-01,  3.95258675e-01,  3.92009289e-01,
#         3.81470062e-01,  3.71767306e-01,  3.62634826e-01,  3.58841075e-01,
#         3.51170295e-01,  3.45157030e-01,  3.49258137e-01,  3.44190466e-01,
#         3.37118061e-01,  3.35601538e-01,  3.30071623e-01,  3.25261142e-01,
#         3.13541069e-01,  3.14908651e-01,  3.09506661e-01,  3.02620762e-01,
#         3.00957581e-01,  2.96330283e-01,  2.89762407e-01,  2.88824567e-01,
#         2.89733933e-01,  2.80075052e-01,  2.72152269e-01,  2.73134819e-01,
#         2.75609431e-01,  2.75061948e-01,  2.70014097e-01,  2.64821016e-01,
#         2.67547654e-01,  2.69348472e-01,  2.65773505e-01,  2.57460105e-01,
#         2.60989264e-01,  2.59938424e-01,  2.60391335e-01,  2.54048762e-01,
#         2.53710266e-01,  2.51391479e-01,  2.53476046e-01,  2.54127836e-01,
#         2.49861154e-01,  2.48268139e-01,  2.52039225e-01,  2.46115203e-01,
#         2.42587868e-01,  2.45782788e-01,  2.37845942e-01,  2.40449210e-01,
#         2.36714099e-01,  2.36421439e-01,  2.28708963e-01,  2.25855150e-01,
#         2.22662153e-01,  2.19548095e-01,  2.14748167e-01,  2.10724767e-01,
#         2.09097749e-01,  2.11338212e-01,  2.07407829e-01,  2.00409401e-01,
#         1.93106358e-01,  1.91862496e-01,  1.91460098e-01,  1.92807654e-01,
#         1.90837580e-01,  1.86058792e-01,  1.87489057e-01,  1.84757571e-01,
#         1.76358142e-01,  1.78448000e-01,  1.74372933e-01,  1.67483664e-01,
#         1.75198205e-01,  1.66716287e-01,  1.66668252e-01,  1.65248046e-01,
#         1.65468908e-01,  1.63060156e-01,  1.61739689e-01,  1.58656061e-01,
#         1.62925249e-01,  1.62448219e-01,  1.56121955e-01,  1.59395446e-01,
#         1.53662474e-01,  1.53035570e-01,  1.57923466e-01,  1.56661914e-01,
#         1.57790810e-01,  1.54610202e-01,  1.58946054e-01,  1.51083203e-01,
#         1.51214900e-01,  1.54011438e-01,  1.50469753e-01,  1.53030116e-01,
#         1.51851927e-01,  1.54432215e-01,  1.54493735e-01,  1.52859313e-01,
#         1.56607176e-01,  1.56596101e-01,  1.59044923e-01,  1.64804827e-01,
#         1.66169221e-01,  1.63300990e-01,  1.68684204e-01,  1.67771687e-01,
#         1.69663725e-01,  1.71819599e-01,  1.76343108e-01,  1.76971738e-01,
#         1.77607775e-01,  1.74103124e-01,  1.79200846e-01,  1.80898571e-01,
#         1.80663245e-01,  1.78338617e-01,  1.79625109e-01,  1.76821027e-01,
#         1.75259760e-01,  1.77037231e-01,  1.93855455e-01,  1.75587799e-01,
#         1.22174587e-01,  1.00103014e-01,  1.09224331e-01,  9.11275563e-02,
#         7.57500078e-02,  7.90186628e-02,  8.89044036e-02,  9.69521327e-02,
#         9.28719055e-02,  8.17901227e-02,  6.63945816e-02,  6.44594711e-02,
#         6.31876216e-02,  6.02641905e-02,  5.03022090e-02,  5.63695080e-02,
#         5.75207572e-02,  5.87264387e-02,  5.46155981e-02,  5.21921950e-02,
#         5.04981248e-02,  4.30361929e-02,  3.97682341e-02,  3.53788410e-02,
#         3.74769215e-02,  3.73965441e-02,  3.11510869e-02,  2.74167364e-02,
#         2.49290817e-02,  2.31754764e-02,  1.64380364e-02,  1.18054687e-02,
#         7.33192915e-03,  1.87935720e-03, -3.37059680e-03, -4.11409333e-03,
#        -4.71593146e-03, -8.78901910e-03, -5.02416730e-02, -4.13956810e-02])
